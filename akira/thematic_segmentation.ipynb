# %%
# libraries
import json
import lzma
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
from IPython.core.display import display, HTML
import re
from nltk.tokenize import RegexpTokenizer
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def text_cleaner(text):
    text_divided = text.splitlines()
    text_divided_clean = " ".join(text_divided)
    return text_divided_clean

# %%
# The file size for some states are too large to open into memory
# This function loads individual cases into memory, parses headnotes and 
# opinions, cleans the text, tokenizes the text, and returns counts of tokens
# for each case.

tokenizer = RegexpTokenizer('\s+', gaps=True)

def get_counts(state):
    cases = []
    with lzma.open("../" + state + '-text/data/data.jsonl.xz', 'r') as jsonl_file:
        for case in jsonl_file:
            c = json.loads(str(case, 'utf-8'))

            date = c['decision_date']
            
            headnotes = text_cleaner(c['casebody']['data']['head_matter'])
            headnotes_tokenized = tokenizer.tokenize(headnotes)
            num_headnotes = len(headnotes_tokenized)

            opinions = c['casebody']['data']['opinions']
            if opinions == []:
                num_opinions = 0
            else:
                opinions = text_cleaner(opinions[0]['text'])
                opinions_tokenized = tokenizer.tokenize(opinions)
                num_opinions = len(opinions_tokenized)
            cases.append({'date':date, 'num_headnotes':num_headnotes, 'headnotes': headnotes, 'num_opinions':num_opinions, 'opinions':opinions})
        return pd.DataFrame(cases)

# %%
# %%time

states = ['Arkansas']
counts_ar = get_counts(states[0])
# counts_il = get_counts(states[1])
# counts_nm = get_counts(states[2])
# counts_nc = get_counts(states[3])
# Out:
# CPU times: user 46.9 s, sys: 700 ms, total: 47.6 s
# Wall time: 47.8 s

# %%
counts_ar.head(20)
# Out:
#           date  num_headnotes  \
# 0      1829-11             29
# 1      1828-05             28
# 2      1836-02             27
# 3   1999-07-15             46
# 4   1999-10-07             39
# 5   1999-10-07             49
# 6   1999-06-10             38
# 7   1999-07-01             64
# 8   1999-10-14             36
# 9   1999-10-14             35
# 10  1999-09-16             35
# 11  1999-09-16             43
# 12  1999-06-17             28
# 13  1999-06-03             60
# 14  1999-10-14             45
# 15  1999-09-16             38
# 16  1999-09-30             40
# 17  1999-06-17             31
# 18  1999-06-03             33
# 19  1999-09-16             50
#
#                                             headnotes  num_opinions  \
# 0   Case No. 4,822a. FISHER v. REIDER. [Hempst. 82...           230
# 1   Case No. 4,785a. FIKES v. BENTLEY. [Hempst. 61...            62
# 2   Case No. 4,863a. FLETCHER v. ELLIS. [Hempst. 3...           616
# 3   Michael NORRIS v. STATE of Arkansas CR 98-1429...          3936
# 4   Roger Allen HAMMON v. STATE of Arkansas CR 98-...          1788
# 5   Joe Louis DANSBY v. STATE of Arkansas CR 97-14...          8076
# 6   David McGREW v. STATE of Arkansas CR 98-426 99...           848
# 7   ST. PAUL FIRE & MARINE INSURANCE COMPANY v. GR...          3050
# 8   Sylvester RICHARDS v. STATE of Arkansas CR 99-...           909
# 9   Patricia OSBURN v. Bryan BUSBEE d/b/a Busbee C...           303
# 10  STATE of Arkansas v. Kenneth STRAWBRIDGE CR 96...           105
# 11  Marilyn SMITH and Derrel Smith v. Phillip SMIT...          1208
# 12  Roger Don FARMER v. STATE of Arkansas CR 99-62...            98
# 13  GHEGAN & GHEGAN, INC., On Behalf of Itself and...          2430
# 14  Earnest M. CRIDDLE Jr. v. STATE of Arkansas CR...          2148
# 15  Anthony L. JOHNSON v. STATE of Arkansas CR 99-...           146
# 16  William J. McCUEN v. STATE of Arkansas CR 97-1...          1307
# 17  Corey SANDERS v. STATE of Arkansas CR 99-628 9...           189
# 18  Donald MALONE v. Linda MALONE 98-833 991 S.W.2...          1979
# 19  Jason N. GATES v. STATE of Arkansas CR 98-1197...          4334
#
#                                              opinions
# 0   OPINION OF THE COIÍRT. This is an action of de...
# 1   OPINION OP THE COURT. This is an appeal from t...
# 2   CROSS, Judge. The record in this case shows th...
# 3   W. H.“Dub” Arnold, Chief Justice. This is a ca...
# 4   Ray Thornton, Justice. Appellant brings this a...
# 5   Annabelle Clinton Imber, Justice. Mr. Joe Loui...
# 6   W. H.“Dub” Arnold, Chief Justice. The appellan...
# 7   Robert L. Brown, Justice. Appellant St. Paul F...
# 8   Lavenski R. Smith, Justice. Appellant, Sylvest...
# 9   Per Curiam. Appellee Bryan Busbee, d/b/a Busbe...
# 10  Per Curiam. The State of Arkansas has petition...
# 11  Donald L. Corbin, Justice. This case involves ...
# 12  Per Curiam. Appellant Roger Don Farmer, by and...
# 13  Annabelle Clinton Imber, Justice. This is an i...
# 14  Donald L. Corbin, Justice. Appellant Earnest M...
# 15  Per Curiam. Appellant Anthony L. Johnson has f...
# 16  Robert L. Brown, Justice. Appellant William J....
# 17  Per Curiam. Corey Sanders, by his attorney, ha...
# 18  Annabelle Clinton Imber, Justice. This appeal ...
# 19  Lavenski R. Smith, Justice. The appellant, Jas...

# %% [markdown]
# ### Do our legal texts really have the linguistic markars?

# %%
# https://www.aclweb.org/anthology/W04-1006.pdf
markars_introduction = ['application for judicial review', 'application to review a decision', 'motion filed by', 'Statement of Claim']

markars_context = ["advise","indicate","concern","request"]

markars_juridical_analysis = ['this court','In reviewing',
                            'Pursuant to section','As I have stated','In the present case']

markars_conclusion = ['note','accept','summarise','scrutinize','think','say','satisfy','discuss','conclude','find','believe','reach','persuade',
                      'agree','indicate','review']

# %%
markars = [markars_introduction, markars_context, markars_juridical_analysis, markars_conclusion]

def markar_detector(text_list):
    for i in range(len(text_list)):
        sentence = text_list[i]
        
        for markar in markars:
            for j in range(len(markar)):
                markar_word = markar[j]
                TF = markar_word in sentence
                if TF == True:
                    if markar == markars_context:
                        type_markar = "context"
                        print("Linguistic markar '"+markar_word+"' detected! Sentence #", i, "of "+str(len(text_list))+". This is",type_markar,"markar.")
                    elif markar == markars_juridical_analysis:
                        type_markar = "juridical analysis"
                        print("Linguistic markar '"+markar_word+"' detected! Sentence #", i, "of "+str(len(text_list))+". This is",type_markar,"markar.") 
                    else:
                        type_markar = "conclusion"
                        print("Linguistic markar '"+markar_word+"' detected! Sentence #", i, "of "+str(len(text_list))+". This is",type_markar,"markar.")

# %% [markdown]
# ### Example 1

# %%
test_text = counts_ar.iloc[4,4]

# %%
# Reference: https://nlpforhackers.io/splitting-text-into-sentences/

from pprint import pprint
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
 
trainer = PunktTrainer()
trainer.INCLUDE_ALL_COLLOCS = True
trainer.train(test_text)
 
tokenizer = PunktSentenceTokenizer(trainer.get_params())

# %%
test_text_list = tokenizer.tokenize(test_text)

# %%
markar_detector(test_text_list)
# Out:
# Linguistic markar 'find' detected! Sentence # 2 of 70. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 6 of 70. This is context markar.
# Linguistic markar 'say' detected! Sentence # 7 of 70. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 15 of 70. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 15 of 70. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 20 of 70. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 21 of 70. This is conclusion markar.
# Linguistic markar 'concern' detected! Sentence # 22 of 70. This is context markar.
# Linguistic markar 'believe' detected! Sentence # 22 of 70. This is conclusion markar.
# Linguistic markar 'this court' detected! Sentence # 24 of 70. This is juridical analysis markar.
# Linguistic markar 'agree' detected! Sentence # 33 of 70. This is conclusion markar.
# Linguistic markar 'concern' detected! Sentence # 34 of 70. This is context markar.
# Linguistic markar 'find' detected! Sentence # 41 of 70. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 46 of 70. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 46 of 70. This is conclusion markar.
# Linguistic markar 'conclude' detected! Sentence # 49 of 70. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 52 of 70. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 65 of 70. This is conclusion markar.
# Linguistic markar 'review' detected! Sentence # 67 of 70. This is conclusion markar.

# %% [markdown]
# ### Example 2

# %%
test_text2 = counts_ar.iloc[5,4]
test_text_list2 = tokenizer.tokenize(test_text2)

markar_detector(test_text_list2)
# Out:
# Linguistic markar 'find' detected! Sentence # 6 of 561. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 25 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 25 of 561. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 61 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 61 of 561. This is conclusion markar.
# Linguistic markar 'conclude' detected! Sentence # 89 of 561. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 94 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 96 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 108 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 108 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 138 of 561. This is conclusion markar.
# Linguistic markar 'conclude' detected! Sentence # 142 of 561. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 145 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 148 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 150 of 561. This is context markar.
# Linguistic markar 'note' detected! Sentence # 162 of 561. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 164 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 166 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 166 of 561. This is conclusion markar.
# Linguistic markar 'advise' detected! Sentence # 168 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 172 of 561. This is context markar.
# Linguistic markar 'think' detected! Sentence # 186 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 187 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 188 of 561. This is conclusion markar.
# Linguistic markar 'think' detected! Sentence # 189 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 190 of 561. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 193 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 196 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 214 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 217 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 225 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 233 of 561. This is context markar.
# Linguistic markar 'request' detected! Sentence # 235 of 561. This is context markar.
# Linguistic markar 'say' detected! Sentence # 237 of 561. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 238 of 561. This is context markar.
# Linguistic markar 'find' detected! Sentence # 246 of 561. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 258 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 258 of 561. This is conclusion markar.
# Linguistic markar 'believe' detected! Sentence # 259 of 561. This is conclusion markar.
# Linguistic markar 'this court' detected! Sentence # 286 of 561. This is juridical analysis markar.
# Linguistic markar 'note' detected! Sentence # 287 of 561. This is conclusion markar.
# Linguistic markar 'this court' detected! Sentence # 301 of 561. This is juridical analysis markar.
# Linguistic markar 'review' detected! Sentence # 301 of 561. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 307 of 561. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 308 of 561. This is conclusion markar.
# Linguistic markar 'conclude' detected! Sentence # 334 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 340 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 348 of 561. This is conclusion markar.
# Linguistic markar 'conclude' detected! Sentence # 350 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 356 of 561. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 369 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 369 of 561. This is conclusion markar.
# Linguistic markar 'note' detected! Sentence # 389 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 410 of 561. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 412 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 416 of 561. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 488 of 561. This is conclusion markar.
# Linguistic markar 'concern' detected! Sentence # 493 of 561. This is context markar.
# Linguistic markar 'say' detected! Sentence # 499 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 503 of 561. This is conclusion markar.
# Linguistic markar 'think' detected! Sentence # 505 of 561. This is conclusion markar.
# Linguistic markar 'concern' detected! Sentence # 510 of 561. This is context markar.
# Linguistic markar 'believe' detected! Sentence # 517 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 521 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 525 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 536 of 561. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 539 of 561. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 539 of 561. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 544 of 561. This is conclusion markar.
# Linguistic markar 'review' detected! Sentence # 546 of 561. This is conclusion markar.
# Linguistic markar 'note' detected! Sentence # 554 of 561. This is conclusion markar.
# Linguistic markar 'motion filed by' detected! Sentence # 555 of 561. This is conclusion markar.
# Linguistic markar 'review' detected! Sentence # 559 of 561. This is conclusion markar.

# %% [markdown]
# ### Example 3

# %%
test_text3 = counts_ar.iloc[19,4]
test_text_list3 = tokenizer.tokenize(test_text3)

markar_detector(test_text_list3)
# Out:
# Linguistic markar 'agree' detected! Sentence # 6 of 222. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 14 of 222. This is conclusion markar.
# Linguistic markar 'advise' detected! Sentence # 38 of 222. This is context markar.
# Linguistic markar 'note' detected! Sentence # 48 of 222. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 73 of 222. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 76 of 222. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 77 of 222. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 82 of 222. This is conclusion markar.
# Linguistic markar 'note' detected! Sentence # 90 of 222. This is conclusion markar.
# Linguistic markar 'note' detected! Sentence # 91 of 222. This is conclusion markar.
# Linguistic markar 'In reviewing' detected! Sentence # 95 of 222. This is juridical analysis markar.
# Linguistic markar 'review' detected! Sentence # 95 of 222. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 106 of 222. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 110 of 222. This is context markar.
# Linguistic markar 'say' detected! Sentence # 115 of 222. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 117 of 222. This is conclusion markar.
# Linguistic markar 'note' detected! Sentence # 122 of 222. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 125 of 222. This is conclusion markar.
# Linguistic markar 'this court' detected! Sentence # 129 of 222. This is juridical analysis markar.
# Linguistic markar 'request' detected! Sentence # 132 of 222. This is context markar.
# Linguistic markar 'note' detected! Sentence # 132 of 222. This is conclusion markar.
# Linguistic markar 'indicate' detected! Sentence # 133 of 222. This is context markar.
# Linguistic markar 'indicate' detected! Sentence # 133 of 222. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 138 of 222. This is context markar.
# Linguistic markar 'this court' detected! Sentence # 151 of 222. This is juridical analysis markar.
# Linguistic markar 'accept' detected! Sentence # 153 of 222. This is conclusion markar.
# Linguistic markar 'accept' detected! Sentence # 162 of 222. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 175 of 222. This is conclusion markar.
# Linguistic markar 'review' detected! Sentence # 175 of 222. This is conclusion markar.
# Linguistic markar 'note' detected! Sentence # 178 of 222. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 181 of 222. This is conclusion markar.
# Linguistic markar 'say' detected! Sentence # 188 of 222. This is conclusion markar.
# Linguistic markar 'agree' detected! Sentence # 191 of 222. This is conclusion markar.
# Linguistic markar 'find' detected! Sentence # 196 of 222. This is conclusion markar.
# Linguistic markar 'review' detected! Sentence # 215 of 222. This is conclusion markar.
# Linguistic markar 'request' detected! Sentence # 216 of 222. This is context markar.
# Linguistic markar 'request' detected! Sentence # 218 of 222. This is context markar.
# Linguistic markar 'say' detected! Sentence # 218 of 222. This is conclusion markar.
# Linguistic markar 'review' detected! Sentence # 220 of 222. This is conclusion markar.
